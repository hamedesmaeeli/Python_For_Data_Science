# %%
from urllib.request import urlopen

url = "http://villa.isfahan.ir/Account/Login?ReturnUrl=%2f"
page = urlopen(url)
print('reponse page is : ',page)

html_bytes = page.read()
html = html_bytes.decode("utf-8")
# Out:
# reponse page is :  <http.client.HTTPResponse object at 0x000002099EB3A0D0>

# %%
print(html)
# Out:
# <!doctype html>
# <html lang="en">
#
# <head>
#     <!-- Basic Page Needs
#     ================================================== -->
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
#     <!-- Specific Meta
#     ================================================== -->
#     <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1">
#     <meta name="description" content="Villa Reservation">
#     <meta name="keywords" content="HTML5, villa, Reservation, Reserve" />
#     <meta name="author" content="Fava">
#
#     <!-- Titles
#     ================================================== -->
#     <title>سامانه آنلاین رزرو ویلا</title>
#
#     <!-- Favicons
#     ================================================== -->
#     <link rel="shortcut icon" href="/Content/CDN/lib/villa-html/assets/images/favicon1.ico">
#
#     <!-- CSS
#     ================================================== -->
#     <link href="/Content/CDN/fonts/font-awesome/font-awesome.min.css" rel="stylesheet" type="text/css" />
#
#     <link rel="stylesheet" href="/Content/CDN/lib/villa-html/assets/css/plugins.min.css">
#     <link rel="stylesheet" href="/Content/CDN/lib/villa-html/assets/css/icons.min.css">
#     <link rel="stylesheet" href="/Content/CDN/lib/villa-html/assets/css/style.css">
#     <link rel="stylesheet" href="/Content/CDN/lib/villa-html/assets/css/color-schemer.css">
#     <script src="/Content/CDN/lib/jquery/3.3.1/jquery-3.3.1.min.js" type="text/javascript"></script>
#
#
#     <!-- RS5.4 Main Stylesheet -->
#
#
#
# </head>
#
# <body>
#     <!-- ======= Main Slider Area =======-->
#     <!-- Header -->
#     <header>
#         <div class="logo">
#             <a href="#"><img src="/Content/CDN/lib/villa-html/assets/images/header_logo.png"></a>
#         </div>
#         <nav>
#             <button id='SignIn'>ورود<i class="fa fa-user" style="margin-left:5px"></i></button>
#
# <form action="/Account/Login?ReturnUrl=%2F" class="login100-form validate-form" method="post"><input name="__RequestVerificationToken" type="hidden" value="6iQs4J0fuNrr33p7J5OOamyl5455Btfm6ujGv_fcm7CvZ33iRi8x1vdQumH_FCMtctJOMVRv1fEXXDgK90blMZwvJ2jG3eVXg8caiy-dggo1" />            <div class='login'>
#                 <button class='close' id='close' type="button"></button>
#                 <div class='top'>
#                     <h2>&nbsp;&nbsp;</h2>
#                 </div>
#                 <div class='user validate-input' data-validate="نام كاربری معتبر مورد نیاز است">
#                     <input id="UserName" name='UserName' placeholder='نــام كــاربری' type='text'>
#                     <span class="field-validation-valid text-danger" data-valmsg-for="UserName" data-valmsg-replace="true" style="text-align:left;"></span>
#                 </div>
#                 <div class='pw validate-input' data-validate="رمز عبور مورد نیاز است">
#                     <input id='Password' name='Password' placeholder='رمز عبــور' type='password'>
#                 </div>
#
#                 <div class='remlog'>
#                     <input type='submit' value='ورود به سامانه'>
#                 </div>
#
#             </div>
# </form>        </nav>
#     </header>
#     <!-- Slider -->
#     <div id="slider">
#         <div class="slides">
#             <div class="slider">
#                 <div class="contentSlide">
#                 </div>
#                 <div class="image">
#                     <img src="/Content/CDN/lib/villa-html/assets/images/1.png">
#                 </div>
#             </div>
#             <div class="slider">
#                 <div class="contentSlide">
#
#                 </div>
#                 <div class="image">
#                     <img src="/Content/CDN/lib/villa-html/assets/images/2.png">
#                 </div>
#             </div>
#             <div class="slider">
#                 <div class="contentSlide">
#
#                 </div>
#                 <div class="image">
#                     <img src="/Content/CDN/lib/villa-html/assets/images/1.png">
#                 </div>
#             </div>
#             <div class="slider">
#
#                 <div class="contentSlide">
#
#                 </div>
#                 <div class="image">
#                     <img src="/Content/CDN/lib/villa-html/assets/images/2.png">
#                 </div>
#             </div>
#         </div>
#     </div>
#     <!-- ====== Section divider ====== -->
#     <div class="vehicle-section-divider night-rider">
#         <div class="contoiner-fluid">
#             <div class="row">
#                 <div class="col-md-12">
#                     <div class="section-divider-content">
#                         <div class="vehicle-border">
#                             <img src="/Content/CDN/lib/villa-html/assets/images/block-car01.png" alt="car-item" />
#                         </div><!-- /.car-border -->
#                     </div><!-- /.section-divider-content -->
#                 </div><!-- /.col-md-12 -->
#             </div><!-- /.row -->
#         </div><!-- /.container-fluid -->
#     </div><!-- /.section-divider -->
#     <!-- ======villa block======= -->
#     <div class="villa-block pd-90">
#         <div class="container">
#             <div class="row tb default-margin-bottom yellow-theme">
#                 <div class="col-md-3 hidden-xs block-navigation-area tb-cell">
#                     <div class="pull-right">
#                         <div class="item-navigation">
#                             <a href="#" class="previous-item">
#                                 <i class="fa fa-angle-left"></i>
#                             </a>
#
#                             <a href="#" class="next-item">
#                                 <i class="fa fa-angle-right"></i>
#                             </a>
#                         </div><!-- /.item-navigation -->
#                     </div><!-- /.pull-right -->
#                 </div><!-- /.col-md-2 -->
#             </div><!-- /.row -->
#
#             <div class="villa-carousel slider-style-two owl-carousel" data-item="[4,2,2,1]">
#                 <div class="item">
#                     <div class="villa-content vehicle-content theme-yellow">
#                         <div class="villa-thumb vehicle-thumbnail">
#                             <a href="/About/Index1">
#                                 <img src="/Content/CDN/lib/villa-html/assets/images/villa/villa-01.jpg" alt="car-item" />
#                             </a>
#                         </div><!-- /.vehicle-thumbnail -->
#                         <div class="vehicle-bottom-content">
#                             <h2 class="villa-name vehicle-title"><a href="#">ویلای چابكسر</a></h2>
#                             <h4 class="villa-desc1">شامل 24 ویلای دوبلكس</h4>
#                             <h5 class="villa-desc2">مجموعه ساحلی</h5>
#                         </div><!-- /.vehicle-bottom-content -->
#                     </div><!-- /.car-content -->
#                 </div><!-- /.item -->
#
#                 <div class="item">
#                     <div class="villa-content vehicle-content theme-yellow">
#                         <div class="villa-thumb vehicle-thumbnail">
#                             <a href="/About/Index2">
#                                 <img src="/Content/CDN/lib/villa-html/assets/images/villa/villa-02.jpg" alt="car-item" />
#                             </a>
#                         </div><!-- /.vehicle-thumbnail -->
#                         <div class="vehicle-bottom-content">
#                             <h2 class="villa-name vehicle-title"><a href="#">زائرسرای مشهد </a></h2>
#                             <h4 class="villa-desc1">شامل مجموعه زائرسرا</h4>
#                             <h5 class="villa-desc2">واقع در مشهد مقدس</h5>
#                         </div><!-- /.vehicle-bottom-content -->
#                     </div><!-- /.car-content -->
#                 </div><!-- /.item -->
#
#                 <div class="item">
#                     <div class="villa-content vehicle-content theme-yellow">
#                         <div class="villa-thumb vehicle-thumbnail">
#                             <a href="/About/Index3">
#                                 <img src="/Content/CDN/lib/villa-html/assets/images/villa/villa-03.jpg" alt="car-item" />
#                             </a>
#                         </div><!-- /.vehicle-thumbnail -->
#                         <div class="vehicle-bottom-content">
#                             <h2 class="villa-name vehicle-title"><a href="#">ویلای چادگان </a></h2>
#                             <h4 class="villa-desc1">شامل مجموعه ویلا واقع در شهر چادگان</h4>
#                             <h5 class="villa-desc2">فاصله تا ساحل :10 دقیقه</h5>
#                         </div><!-- /.vehicle-bottom-content -->
#                     </div><!-- /.car-content -->
#                 </div><!-- /.item -->
#
#                 <div class="item">
#                     <div class="villa-content vehicle-content theme-yellow">
#                         <div class="villa-thumb vehicle-thumbnail">
#                             <a href="/About">
#                                 <img src="/Content/CDN/lib/villa-html/assets/images/villa/villa-04.jpg" alt="car-item" />
#                             </a>
#                         </div><!-- /.vehicle-thumbnail -->
#                         <div class="vehicle-bottom-content">
#                             <h2 class="villa-name vehicle-title"><a href="#">ویلای عباس آباد </a></h2>
#                             <h4 class="villa-desc1">شامل5طبقه واقع در شهر عباس آباد </h4>
#                             <h5 class="villa-desc2">مجموعه ساحلی</h5>
#                         </div><!-- /.vehicle-bottom-content -->
#                     </div><!-- /.car-content -->
#                 </div><!-- /.item -->
#             </div><!-- /.villa-carousel -->
#             <!-- block-navigation-area -->
#             <div class="block-navigation-area visible-xs-block">
#
#             </div><!-- /.block-navigation-area -->
#         </div><!-- /.container  -->
#     </div><!-- /.villa-area -->
#     <!-- ====== App block ====== -->
#     <!--<div class="app-block bg-gray-color mr-top-35 mr-btm-5" style="display:none">
#         <div class="container-large-device">
#             <div class="container">
#                 <div class="row tb">
#                     <div class="col-md-6 tb-cell">
#                         <div class="mobile-app-details">
#                             <h4 class="title red-color">اپلیكیشن همراه رزرو ویلا</h4>
#                             <h6 class="top-subtitle">شما می توانید این سامانه را همراه خود داشته باشید</h6>
#
#                             <div class="app-location-link">
#                                 <button class="btn btn-primery" style="font-size:40px" onclick="fn_GetAndroidApp()">
#                                     <i class="fa fa-android"></i>لينك دريافت اپليكيشن
#                                 </button>
#
#                             </div>--><!-- /.app-location-link -->
#                         <!--</div>--><!-- /.mobile-app-details -->
#                     <!--</div>--><!-- /.col-md-6 -->
#                     <!--<div class="col-md-6 tb-cell">
#                         <div class="app-mokeup">
#                             <img src="/Content/CDN/lib/villa-html/assets/images/mobile.png" alt="mobile" />
#                         </div>--><!-- /.app-mokeup -->
#                     <!--</div>--><!-- /.col-md-6 -->
#                 <!--</div>--><!-- /.row -->
#             <!--</div>--><!-- /.container -->
#         <!--</div>--><!-- /.container-large-device -->
#     <!--</div>-->
#     <!-- /.app-block -->
#     <!-- ====== Popular Vehicle Block ====== -->
#     <div class="popular-vehicle-block pd-90 ex-pdt-102 ex-pdtm-72" style="display:none">
#         <div class="container">
#             <div class="row tb default-margin-bottom yellow-theme">
#                 <!-- block-title-area -->
#                 <!-- block-navigation-area -->
#                 <div class="col-md-3 col-sm-4 hidden-xs block-navigation-area tb-cell">
#                     <div class="pull-right">
#                         <div class="item-navigation hidden-xs">
#                             <a href="#" class="previous-item">
#                                 <i class="fa fa-angle-left"></i>
#                             </a>
#                             <a href="#" class="next-item">
#                                 <i class="fa fa-angle-right"></i>
#                             </a>
#                         </div><!-- /.item-navigation -->
#                     </div><!-- /.pull-right -->
#                 </div><!-- /.col-md-3 -->
#             </div><!-- /.row -->
#
#
#             <div class="vehicle-slider slider-style-two owl-carousel" data-item="[4,2,1,1]">
#                 <div class="item">
#                     <div class="vehicle-content theme-yellow">
#                         <div class="vehicle-thumbnail">
#                             <a href="#">
#                                 <img src="/Content/CDN/lib/villa-html/assets/images/blog/blog-two.png" />
#                             </a>
#                         </div>
#                     </div>
#                 </div><!-- /.item -->
#
#                 <div class="item">
#                     <div class="vehicle-content theme-yellow">
#                         <div class="vehicle-thumbnail">
#                             <a href="#">
#                                 <img src="/Content/CDN/lib/villa-html/assets/images/blog/blog-one.png" />
#                             </a>
#                         </div>
#                     </div>
#                 </div><!-- /.item -->
#
#                 <div class="item">
#                     <div class="vehicle-content theme-yellow">
#                         <div class="vehicle-thumbnail">
#                             <a href="#">
#                                 <img src="/Content/CDN/lib/villa-html/assets/images/blog/blog-three.png" />
#                             </a>
#                         </div>
#                     </div>
#                 </div><!-- /.item -->
#
#                 <div class="item">
#                     <div class="vehicle-content theme-yellow">
#                         <div class="vehicle-thumbnail">
#                             <a href="#">
#                                 <img src="/Content/CDN/lib/villa-html/assets/images/blog/blog-four.png" />
#                             </a>
#                         </div>
#                     </div>
#                 </div><!-- /.item -->
#             </div>
#         </div><!-- /.container  -->
#     </div>
#     <!-- ======footer area======= -->
#     <div class="container footer-top-border">
#     </div><!-- /.container -->
#
#     <footer class="footer-block bg-black" style="background-image: url(/Content/CDN/lib/villa-html/assets/images/footer-bg.png);">
#         <div class="container">
#             <!-- footer-top-block -->
#             <div class="footer-top-block yellow-theme">
#                 <div class="row">
#                     <div class="col-md-6 col-sm-6">
#                         <div class="widget widget_photo_gallery">
#                             <h3 class="widget-title">
#                                 پیوندهای مرتبط
#                             </h3><!-- /.widget-title -->
#                             <ul class="photo-gallery-content">
#                                 <li>
#                                     <a href="#">
#                                         <img src="/Content/CDN/lib/villa-html/assets/images/instagram/instagram-01.png" alt="instagram" />
#                                     </a>
#                                 </li>
#                                 <li>
#                                     <a href="#">
#                                         <img src="/Content/CDN/lib/villa-html/assets/images/instagram/instagram-02.png" alt="instagram" />
#                                     </a>
#                                 </li>
#                                 <li>
#                                     <a href="#">
#                                         <img src="/Content/CDN/lib/villa-html/assets/images/instagram/instagram-03.png" alt="instagram" />
#                                     </a>
#                                 </li>
#                                 <li>
#                                     <a href="#">
#                                         <img src="/Content/CDN/lib/villa-html/assets/images/instagram/instagram-04.png" alt="instagram" />
#                                     </a>
#                                 </li>
#
#
#                             </ul><!-- /.instagram-image-content -->
#                         </div><!-- /.widget -->
#                     </div>
#                     <div class="col-md-6 col-sm-6">
#                         <div class="widget widget_hot_contact">
#                             <h3 class="widget-title">
#                                 با ما در تماس باشید
#                             </h3><!-- /.widget-title -->
#                             <ul class="listRight">
#                                 <li><a href="#"><i class="fa fa-envelope"></i>refah@isfahan.ir</a></li>
#                                 <li><a href="#"><i class="fa fa-phone"></i>(+98-031)32152662</a></li>
#                                 <li>
#                                     <a href="#">
#                                         <i class="fa fa-map-marker"></i>  شهرداری اصفهان
#                                         میدان امام حسین
#                                     </a>
#                                 </li>
#                             </ul>
#                         </div><!-- /.widget -->
#                         <!-- <div class="widget widget_newsletter">
#                             <h3 class="widget-title">اشتراك خـــبرنــامه سامانه</h3>
#                             <form action="#" class="subscribes-newsletter" method="get">
#                                 <label>جهت اطلاع از آخرین اخبار ،اطلاعات خود را وارد كنید</label>
#                                 <div class="input-group">
#                                     <input type="search" name="s" placeholder="ایمیل خود را وارد كنید" class="form-controller">
#                                     <span class="input-group-btn">
#                                         <button type="submit" class="btn btn-primary">
#                                                 <span class="fa fa-paper-plane"></span>
#                                         </button>
#                                     </span>
#                                 </div>
#                             </form>
#                         </div> -->
#                     </div>
#                 </div><!-- /.row -->
#             </div><!-- /.footer-top-block -->
#             <!-- footer-bottom-block -->
#             <div class="footer-bottom-block">
#                 <div class="row">
#                     <div class="col-md-12">
#                         <div>
#                             <span>
#                                 کلیه حقوق این سایت متعلق به <a href="http://new.isfahan.ir" class="sub-footer__link">شهرداری اصفهان </a> میباشد------
#                                 تولید، طراحی و پشتیبانی فنی <a href="http://ict.isfahan.ir/">سازمان فناوری اطلاعات و ارتباطات شهرداری اصفهان</a>
#                             </span>
#                         </div><!-- /.bottom-top-content -->
#                     </div><!-- /.col-md-9 -->
#                     <!-- <div class="col-md-3">
#                        <div class="bottom-content-right">
#                            <div class="social-profile">
#                                <span class="social-profole-title">مارادرشبكه های مجازی دنبال كنید</span>
#                                <a href="#"><i class="fa fa-instagram"></i></a>
#                                <a href="#"><i class="fa fa-heart"></i></a>
#                                <a href="#"><i class="fa fa-facebook"></i></a>
#                                <a href="#"><i class="fa fa-twitter"></i></a>
#                            </div>
#                        </div>
#                     </div>-->
#                 </div><!-- /.row -->
#             </div><!-- /.footer-bottom-block -->
#         </div><!-- /.container -->
#     </footer><!-- /.footer-block -->
#     <!-- All The JS Files
#     ================================================== -->
#     <script src="/Content/CDN/lib/villa-html/assets/js/plugins.min.js"></script>
#     <script src="/Content/CDN/lib/villa-html/assets/js/carrent.min.js"></script> <!-- main-js -->
#     <script src="/Content/CDN/lib/villa-html/assets/js/index.js"></script>
#
#     <script>
#         $().ready(function () {
#             $("br").remove();
#             $('#CaptchaImage').addClass("wrap-input100 validate-input");
#             $('#CaptchaImage').css("margin-bottom", "2%");
#             $('#CaptchaInputText').addClass("validate-input");
#             $('#CaptchaInputText').prop("placeholder", "حاصل عبارت بالا را وارد نماييد");
#             $('#CaptchaInputText').css("text-align", "center");
#         });
#         function fn_GetAndroidApp() {
#             window.location.href="/Public/App";
#         }
#     </script>
#
# </body>
# </html>

# %%
title_index = html.find("<title>")
title_index
# Out:
# 662

# %%
start_index = title_index + len("<title>")
start_index
# Out:
# 669

# %%
end_index =  html.find("</title>")
end_index
# Out:
# 692

# %%
title = html[start_index:end_index]
title
# Out:
# 'سامانه آنلاین رزرو ویلا'
